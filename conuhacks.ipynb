# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Jabba\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv(r"C:\Users\Jabba\Downloads\Incidents métro.csv")

# %%
def convert_to_minutes(time_string):
    try:
        # Split the string into hours and minutes
        hours, minutes = map(int, time_string.split(':'))

        # Convert hours to minutes and add to the total
        return hours * 60 + minutes
    except ValueError:
        return None  # Handle invalid input gracefully

        return total_minutes

df1['Time between'] = df1['Time between'].apply(convert_to_minutes)

# %%
df1.head()
# Out:
#   Numero d'incident Type d'incident Cause primaire Cause secondaire  \
# 0         S01011901               S         Autres           Autres
# 1         S01011902               S         Autres           Autres
# 2         S01011903               S         Autres           Autres
# 3         S01011904               S         Autres           Autres
# 4         S01011905               S         Autres           Autres
#
#     Symptome         Ligne Numéro de tournée Heure de l'incident  \
# 0  Clientèle  Ligne orange                 #                2:56
# 1  Clientèle  Ligne orange                 #                2:56
# 2  Clientèle   Ligne verte                 #                3:35
# 3  Clientèle   Ligne verte                 #                4:56
# 4  Clientèle   Ligne verte                 #                5:25
#
#   Heure de reprise  Time between  ... Porte Urgence métro CAT Évacuation  \
# 0             3:32            36  ...     0             0   0          #
# ...

# %%
df2=df1

# %%
df2=df1[df1["Type d\'incident"] == 'S']

# %%
avg_time_by_group1 = df2.groupby(['Code de lieu', 'Cause secondaire'])['Time between'].mean().reset_index()

avg_time_by_group1.head()


avg_time_by_group2 = df2.groupby(['Code de lieu', 'Symptome'])['Time between'].mean().reset_index()

avg_time_by_group2.head()
# Out:
#                          Code de lieu                            Symptome  \
# 0                                2999  Feu, fumée, odeur, produit, etc...
# 1                                9999               Exploitation stations
# 2                                9999                   Équipements fixes
# 3       ARRIERE-GARE HONORE-BEAUGRAND                           Clientèle
# 4  ATELIER DE LA VOIE ET ABRI DU PARC               Exploitation stations
#
#    Time between
# 0     56.000000
# 1    201.333333
# 2    197.000000
# 3     24.000000
# 4     51.000000

# %%
avg_time_by_groupCause2nd =avg_time_by_group1

avg_time_by_groupSympt = avg_time_by_group2

# %%
# Convert 'time_between' to timedelta
avg_time_by_groupCause2nd['Time between'] = pd.to_timedelta(avg_time_by_groupCause2nd['Time between'], unit='m')

# Extract hours and minutes from timedelta and combine into a single column
avg_time_by_groupCause2nd['time_formatted'] = avg_time_by_groupCause2nd['Time between'].dt.components['hours'].astype(str).str.zfill(2) + ':' + avg_time_by_groupCause2nd['Time between'].dt.components['minutes'].astype(str).str.zfill(2)


# Convert 'time_between' to timedelta
avg_time_by_groupSympt['Time between'] = pd.to_timedelta(avg_time_by_groupSympt['Time between'], unit='m')

# Extract hours and minutes from timedelta and combine into a single column
avg_time_by_groupSympt['time_formatted'] = avg_time_by_groupSympt['Time between'].dt.components['hours'].astype(str).str.zfill(2) + ':' + avg_time_by_groupSympt['Time between'].dt.components['minutes'].astype(str).str.zfill(2)

# %%
avg_time_by_groupCause2nd.head()
# Out:
#                          Code de lieu Cause secondaire           Time between  \
# 0                                2999           Autres        0 days 00:56:00
# 1                                9999           Autres        0 days 03:18:18
# 2       ARRIERE-GARE HONORE-BEAUGRAND           Autres        0 days 00:24:00
# 3  ATELIER DE LA VOIE ET ABRI DU PARC           Autres        0 days 00:51:00
# 4                              Acadie           Autres 0 days 01:13:39.600000
#
#   time_formatted
# 0          00:56
# 1          03:18
# 2          00:24
# 3          00:51
# 4          01:13

# %%
avg_time_by_groupSympt["Time between"] = avg_time_by_groupSympt['Time between'].astype(str)

# %%
avg_time_by_groupSympt['Time between']

for i in range(len(avg_time_by_groupSympt)):
    avg_time_by_groupSympt['time_formatted'][i] = avg_time_by_groupSympt['Time between'][i].split("days")[1].strip()[:5]
# Out:
# C:\Users\Jabba\AppData\Local\Temp\ipykernel_18332\3867282852.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
avg_time_by_groupSympt.head()
# Out:
#                          Code de lieu                            Symptome  \
# 0                                2999  Feu, fumée, odeur, produit, etc...
# 1                                9999               Exploitation stations
# 2                                9999                   Équipements fixes
# 3       ARRIERE-GARE HONORE-BEAUGRAND                           Clientèle
# 4  ATELIER DE LA VOIE ET ABRI DU PARC               Exploitation stations
#
#                 Time between time_formatted
# 0            0 days 00:56:00          00:56
# 1  0 days 03:21:19.999999998          03:21
# 2            0 days 03:17:00          03:17
# 3            0 days 00:24:00          00:24
# 4            0 days 00:51:00          00:51

# %%
df2.head()
# Out:
#   Numero d'incident Type d'incident Cause primaire Cause secondaire  \
# 0         S01011901               S         Autres           Autres
# 1         S01011902               S         Autres           Autres
# 2         S01011903               S         Autres           Autres
# 3         S01011904               S         Autres           Autres
# 4         S01011905               S         Autres           Autres
#
#     Symptome         Ligne Numéro de tournée Heure de l'incident  \
# 0  Clientèle  Ligne orange                 #                2:56
# 1  Clientèle  Ligne orange                 #                2:56
# 2  Clientèle   Ligne verte                 #                3:35
# 3  Clientèle   Ligne verte                 #                4:56
# 4  Clientèle   Ligne verte                 #                5:25
#
#   Heure de reprise  Time between  ... Porte Urgence métro CAT Évacuation  \
# 0             3:32            36  ...     0             0   0          #
# ...

# %%
dfh1=df2

# %%
dfh1['Start time'] = dfh1['Heure de l\'incident'].str.split(':').str[0] + ':00'

dfh1.head()
# Out:
# C:\Users\Jabba\AppData\Local\Temp\ipykernel_18332\1007452388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfh1['Start time'] = dfh1['Heure de l\'incident'].str.split(':').str[0] + ':00'
#   Numero d'incident Type d'incident Cause primaire Cause secondaire  \
# 0         S01011901               S         Autres           Autres
# 1         S01011902               S         Autres           Autres
# 2         S01011903               S         Autres           Autres
# 3         S01011904               S         Autres           Autres
# 4         S01011905               S         Autres           Autres
#
#     Symptome         Ligne Numéro de tournée Heure de l'incident  \
# ...

# %%
avg_time_by_groupIncidentHeure = dfh1.groupby(['Code de lieu', 'Start time'])['Time between'].mean().reset_index()

avg_time_by_groupIncidentHeure.head()
# Out:
#   Code de lieu Start time  Time between
# 0         2999       7:00          56.0
# 1         9999      11:00         264.5
# 2         9999      12:00          45.5
# 3         9999      13:00          71.0
# 4         9999      14:00           9.0

# %%
# Convert 'time_between' to timedelta
avg_time_by_groupIncidentHeure['Time between'] = pd.to_timedelta(avg_time_by_groupIncidentHeure['Time between'], unit='m')

# Extract hours and minutes from timedelta and combine into a single column
avg_time_by_groupIncidentHeure['time_formatted'] = avg_time_by_groupIncidentHeure['Time between'].dt.components['hours'].astype(str).str.zfill(2) + ':' + avg_time_by_groupIncidentHeure['Time between'].dt.components['minutes'].astype(str).str.zfill(2)

avg_time_by_groupIncidentHeure["Time between"] = avg_time_by_groupIncidentHeure['Time between'].astype(str)

avg_time_by_groupIncidentHeure['Time between']

for i in range(len(avg_time_by_groupIncidentHeure)):
    avg_time_by_groupIncidentHeure['time_formatted'][i] = avg_time_by_groupIncidentHeure['Time between'][i].split("days")[1].strip()[:5]
# Out:
# C:\Users\Jabba\AppData\Local\Temp\ipykernel_18332\109416608.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
avg_time_by_groupIncidentHeure.head()
# Out:
#   Code de lieu Start time     Time between time_formatted
# 0         2999       7:00  0 days 00:56:00          00:56
# 1         9999      11:00  0 days 04:24:30          04:24
# 2         9999      12:00  0 days 00:45:30          00:45
# 3         9999      13:00  0 days 01:11:00          01:11
# 4         9999      14:00  0 days 00:09:00          00:09

# %%
#filtering out all numbered stations

avg_time_by_groupIncidentHeure = avg_time_by_groupIncidentHeure[~avg_time_by_groupIncidentHeure['Code de lieu'].str.contains('\d', regex=True)]
avg_time_by_groupCause2nd = avg_time_by_groupCause2nd[~avg_time_by_groupCause2nd['Code de lieu'].str.contains('\d', regex=True)]
avg_time_by_groupSympt = avg_time_by_groupSympt[~avg_time_by_groupSympt['Code de lieu'].str.contains('\d', regex=True)]
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Jabba\AppData\Local\Temp\ipykernel_18332\2668776764.py:3: SyntaxWarning: invalid escape sequence '\d'
#   avg_time_by_groupIncidentHeure = avg_time_by_groupIncidentHeure[~avg_time_by_groupIncidentHeure['Code de lieu'].str.contains('\d', regex=True)]
# C:\Users\Jabba\AppData\Local\Temp\ipykernel_18332\2668776764.py:4: SyntaxWarning: invalid escape sequence '\d'
#   avg_time_by_groupCause2nd = avg_time_by_groupCause2nd[~avg_time_by_groupCause2nd['Code de lieu'].str.contains('\d', regex=True)]
# C:\Users\Jabba\AppData\Local\Temp\ipykernel_18332\2668776764.py:5: SyntaxWarning: invalid escape sequence '\d'
# ...

# %%
avg_time_by_groupSympt.head()
# Out:
#                          Code de lieu                            Symptome  \
# 3       ARRIERE-GARE HONORE-BEAUGRAND                           Clientèle
# 4  ATELIER DE LA VOIE ET ABRI DU PARC               Exploitation stations
# 5                              Acadie                           Clientèle
# 6                              Acadie               Exploitation stations
# 7                              Acadie  Feu, fumée, odeur, produit, etc...
#
#                 Time between time_formatted
# 3            0 days 00:24:00          00:24
# 4            0 days 00:51:00          00:51
# 5  0 days 01:15:08.275862070          01:15
# 6            0 days 01:12:48          01:12
# 7            0 days 00:48:00          00:48

# %%
avg_time_by_groupIncidentHeure=avg_time_by_groupIncidentHeure.drop(columns=['Time between'])
avg_time_by_groupIncidentHeure=avg_time_by_groupIncidentHeure.rename(columns={'time_formatted':'Incident Time'})

avg_time_by_groupCause2nd=avg_time_by_groupCause2nd.drop(columns=['Time between'])
avg_time_by_groupCause2nd=avg_time_by_groupCause2nd.rename(columns={'time_formatted':'Incident Time'})

avg_time_by_groupSympt=avg_time_by_groupSympt.drop(columns=['Time between'])
avg_time_by_groupSympt=avg_time_by_groupSympt.rename(columns={'time_formatted':'Incident Time'})
